# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns
from matplotlib import rcParams

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Importing the loan prediction dataset

# %%
file='C:/Users/OFFICE/Desktop/bOOK/data science/practice problems/loan prediction/train_u6lujuX_CVtuZ9i.csv'
loan_pred_data = pd.read_csv(file)
loan_pred_data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_pred_data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
len(loan_pred_data)
# Out:
# 614

# %%
del loan_pred_data['Loan_ID']

# %%
#loan_pred_data.head()

# %%
loan_df = loan_pred_data
loan_df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.6+ KB

# %% [markdown]
# ### checking out the dataset to see if the attributes of the data are of the corect data types with the above line of code loan_df.info(), we find out that there are no wrong data types to the attributes of the loan prediction data set. I also deleted the Loan_ID column since it would not be used for any computation in the data analysis. the loan_df DataFrame would be used for analysis.

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# We would clean the data and turn categorical variables to statistical variables

# %%
loan_df.dropna(subset=['Gender','Dependents','Self_Employed','Married','Education'], axis=0, inplace=True)

# %%
loan_df.isnull().any()
# Out:
# Gender               False
# Married              False
# Dependents           False
# Education            False
# Self_Employed        False
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount            True
# Loan_Amount_Term      True
# Credit_History        True
# Property_Area        False
# Loan_Status          False
# dtype: bool

# %% [markdown]
# the LoanAmount, Loan_Amount_Term and Credit_History coulmns still have missing data. I would replace the missing data with mean values to enable us peform descriptive statistics on the dataset.

# %%
#mean_LoanAmount = loan_df['LoanAmount'].mean()
#loan_df['LoanAmount'].replace(np.nan,mean_LoanAmount)

# %%
#mean_credit_hist = loan_df['Credit_History'].mean()
#loan_df['Credit_History'].replace(np.nan,mean_credit_hist)

# %%
#mean_LoanAmtTrm = loan_df['Loan_Amount_Term'].mean()
#loan_df['Loan_Amount_Term'].replace(np.nan,mean)

# %%
loan_df.isnull().any()
# Out:
# Gender               False
# Married              False
# Dependents           False
# Education            False
# Self_Employed        False
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount            True
# Loan_Amount_Term      True
# Credit_History        True
# Property_Area        False
# Loan_Status          False
# dtype: bool

# %%
loan_df.dropna(subset=['LoanAmount','Loan_Amount_Term','Credit_History'], axis=0,inplace=True)

# %%
loan_df.shape
# Out:
# (480, 12)

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
# Gender               480 non-null object
# Married              480 non-null object
# Dependents           480 non-null object
# Education            480 non-null object
# Self_Employed        480 non-null object
# ApplicantIncome      480 non-null int64
# CoapplicantIncome    480 non-null float64
# LoanAmount           480 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       480 non-null float64
# Property_Area        480 non-null object
# Loan_Status          480 non-null object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 48.8+ KB

# %%
loan_df.describe(include='all')
# Out:
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     480     480        480       480           480       480.000000
# unique      2       2          4         2             2              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      394     311        274       383           414              NaN
# mean      NaN     NaN        NaN       NaN           NaN      5364.231250
# std       NaN     NaN        NaN       NaN           NaN      5668.251251
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# 25%       NaN     NaN        NaN       NaN           NaN      2898.750000
# 50%       NaN     NaN        NaN       NaN           NaN      3859.000000
# 75%       NaN     NaN        NaN       NaN           NaN      5852.500000
# max       NaN     NaN        NaN       NaN           NaN     81000.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %% [markdown]
# from the descriptive statistics of the data in the above cell; out of 480 people applying for the loan application, there are more males(394) applying for loans in the gender category, in the married category 311 people are married and 383 are educated and 414 people are not self employed.
# The much number of males applying for loans could be as a result that most males are bread winners in the family or there are more males trying to run a business. The Married people applying for loans are much, could this mean more couples are going into financial crisis or looking at the number of self employed people applying for loans are they trying to start a side business to become entrpreneurs?

# %%
#lets check for correlation
loan_df.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.112588    0.495310
# CoapplicantIncome        -0.112588           1.000000    0.190740
# LoanAmount                0.495310           0.190740    1.000000
# Loan_Amount_Term         -0.010838          -0.005775    0.050867
# Credit_History           -0.056152          -0.008692   -0.040773
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.010838       -0.056152
# CoapplicantIncome         -0.005775       -0.008692
# LoanAmount                 0.050867       -0.040773
# Loan_Amount_Term           1.000000        0.032937
# Credit_History             0.032937        1.000000

# %%
#i will get dummy variables of all categorical variables here.
pd.get_dummies(loan_df[['Gender','Married','Education','Self_Employed']]).head()
# Out:
#    Gender_Female  Gender_Male  Married_No  Married_Yes  Education_Graduate  \
# 1              0            1           0            1                   1
# 2              0            1           0            1                   1
# 3              0            1           0            1                   0
# 4              0            1           1            0                   1
# 5              0            1           0            1                   1
#
#    Education_Not Graduate  Self_Employed_No  Self_Employed_Yes
# 1                       0                 1                  0
# 2                       0                 0                  1
# 3                       1                 1                  0
# 4                       0                 1                  0
# 5                       0                 0                  1

# %%
loan_df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
# 5   Male     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# ...

# %%
plt.figure(figsize=(5, 5))
sns.distplot(loan_df['LoanAmount'], color='g', bins=50, hist_kws={'alpha': 0.4});

# %%
plt.figure(figsize=(5, 5))
sns.distplot(loan_df['ApplicantIncome'], color='g', bins=100, hist_kws={'alpha': 0.4});

# %%
plt.figure(figsize=(5, 5))
sns.distplot(loan_df['CoapplicantIncome'], color='g', bins=100, hist_kws={'alpha': 0.4});
