# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns
from matplotlib import rcParams

# %matplotlib inline 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_j = pd.read_csv('dow_jones.csv', delimiter=',')

# %%
df_j.head()
# Out:
#    quarter stock       date    open    high     low   close     volume  \
# 0        1    AA   1/7/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1        1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2        1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3        1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4        1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume next_weeks_open next_weeks_close  \
# 0                    NaN          $16.71           $15.97
# ...

# %% [markdown]
# ### Accessing the main DataFrame components

# %%
df_j = pd.read_csv('dow_jones.csv', delimiter=',')
columns = df_j.columns
index = df_j.index
data = df_j.values

# %%
index
# Out:
# RangeIndex(start=0, stop=750, step=1)

# %%
columns
# Out:
# Index(['quarter', 'stock', 'date', 'open', 'high', 'low', 'close', 'volume',
#        'percent_change_price', 'percent_change_volume_over_last_wk',
#        'previous_weeks_volume', 'next_weeks_open', 'next_weeks_close',
#        'percent_change_next_weeks_price', 'days_to_next_dividend',
#        'percent_return_next_dividend'],
#       dtype='object')

# %%
data
# Out:
# array([[1, 'AA', '1/7/2011', ..., -4.42849, 26, 0.182704],
#        [1, 'AA', '1/14/2011', ..., -2.4706599999999996, 19, 0.187852],
#        [1, 'AA', '1/21/2011', ..., 1.63831, 12, 0.189994],
#        ...,
#        [2, 'XOM', '6/10/2011', ..., -1.225, 61, 0.58912],
#        [2, 'XOM', '6/17/2011', ..., -2.3776200000000003, 54,
#         0.5947859999999999],
#        [2, 'XOM', '6/24/2011', ..., 6.672739999999999, 47, 0.612139]],
#       dtype=object)

# %%
type(index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
issubclass(pd.RangeIndex, pd.Index)
# Out:
# True

# %% [markdown]
# ### Understanding the data types

# %%
df_j.dtypes
# Out:
# quarter                                 int64
# stock                                  object
# date                                   object
# open                                   object
# high                                   object
# low                                    object
# close                                  object
# volume                                  int64
# percent_change_price                  float64
# percent_change_volume_over_last_wk    float64
# previous_weeks_volume                 float64
# next_weeks_open                        object
# next_weeks_close                       object
# percent_change_next_weeks_price       float64
# days_to_next_dividend                   int64
# percent_return_next_dividend          float64
# dtype: object

# %%
 df_j.get_dtype_counts()
# Out:
# float64    5
# int64      3
# object     8
# dtype: int64

# %% [markdown]
# ### selecting a singe column of data as series

# %%
df_j['volume']
# Out:
# 0      239655616
# 1      242963398
# 2      138428495
# 3      151379173
# 4      154387761
# 5      114691279
# 6       80023895
# 7      132981863
# 8      109493077
# 9      114332562
# 10     130374108
# 11      95550392
# 12      45102042
# 13      25913713
# 14      38824728
# 15      51427274
# 16      39501680
# 17      43746998
# 18      28564910
# 19      39654146
# 20      38985037
# 21      37613429
# 22      41757526
# 23      30798332
# 24      36258120
# 25      18834664
# 26      29594221
# 27      34929673
# 28      22770062
# 29      21809411
#          ...
# 720     50174214
# 721     72100710
# 722     69585912
# 723     82375230
# 724     44519431
# 725     48382262
# 726     45662991
# 727     23073491
# 728     47159044
# 729     46668727
# 730     42649301
# 731     56695842
# 732     35560853
# 733     48156051
# 734     58746396
# 735     68996550
# 736     75602550
# 737     77569311
# 738     75566590
# 739     81056144
# 740     43378708
# ...

# %%
df_j.volume
# Out:
# 0      239655616
# 1      242963398
# 2      138428495
# 3      151379173
# 4      154387761
# 5      114691279
# 6       80023895
# 7      132981863
# 8      109493077
# 9      114332562
# 10     130374108
# 11      95550392
# 12      45102042
# 13      25913713
# 14      38824728
# 15      51427274
# 16      39501680
# 17      43746998
# 18      28564910
# 19      39654146
# 20      38985037
# 21      37613429
# 22      41757526
# 23      30798332
# 24      36258120
# 25      18834664
# 26      29594221
# 27      34929673
# 28      22770062
# 29      21809411
#          ...
# 720     50174214
# 721     72100710
# 722     69585912
# 723     82375230
# 724     44519431
# 725     48382262
# 726     45662991
# 727     23073491
# 728     47159044
# 729     46668727
# 730     42649301
# 731     56695842
# 732     35560853
# 733     48156051
# 734     58746396
# 735     68996550
# 736     75602550
# 737     77569311
# 738     75566590
# 739     81056144
# 740     43378708
# ...

# %%
type(df_j['volume'])
# Out:
# pandas.core.series.Series

# %%
#to verify if its a series
vol = df_j['volume']
vol.to_frame()
# Out:
#         volume
# 0    239655616
# 1    242963398
# 2    138428495
# 3    151379173
# 4    154387761
# 5    114691279
# 6     80023895
# 7    132981863
# 8    109493077
# 9    114332562
# 10   130374108
# 11    95550392
# 12    45102042
# 13    25913713
# 14    38824728
# 15    51427274
# 16    39501680
# 17    43746998
# 18    28564910
# 19    39654146
# 20    38985037
# 21    37613429
# 22    41757526
# 23    30798332
# 24    36258120
# 25    18834664
# 26    29594221
# 27    34929673
# 28    22770062
# 29    21809411
# ..         ...
# 720   50174214
# 721   72100710
# 722   69585912
# 723   82375230
# 724   44519431
# 725   48382262
# 726   45662991
# 727   23073491
# 728   47159044
# 729   46668727
# 730   42649301
# 731   56695842
# 732   35560853
# 733   48156051
# 734   58746396
# 735   68996550
# 736   75602550
# 737   77569311
# 738   75566590
# 739   81056144
# 740   43378708
# 741   81596868
# 742  113805856
# 743   99678100
# 744   86758820
# 745   68230855
# ...

# %% [markdown]
# ### callingf series method

# %%
s_attr_meth = set(dir(pd.Series))
len(s_attr_meth)
# Out:
# 464

# %%
sd_attr_meth = set(dir(pd.DataFrame))
len(sd_attr_meth)
# Out:
# 460

# %%
len(s_attr_meth & sd_attr_meth)
# Out:
# 399

# %%
cl = df_j['close']
cl.head()
# Out:
# 0    $16.42
# 1    $15.97
# 2    $15.79
# 3    $16.13
# 4    $17.14
# Name: close, dtype: object

# %%
cl.value_counts()
# Out:
# $33.07     3
# $46.25     3
# $41.52     3
# $36.00     3
# $79.08     2
# $30.65     2
# $20.82     2
# $21.46     2
# $66.09     2
# $65.27     2
# $65.53     2
# $19.75     2
# $18.34     2
# $37.15     2
# $18.82     2
# $58.98     2
# $37.08     2
# $36.39     2
# $17.28     2
# $45.74     2
# $82.52     2
# $50.29     2
# $14.25     2
# $54.63     2
# $31.26     2
# $12.31     2
# $17.14     2
# $35.63     2
# $20.37     2
# $88.98     2
#           ..
# $40.81     1
# $34.38     1
# $39.45     1
# $60.70     1
# $56.68     1
# $34.95     1
# $40.41     1
# $68.18     1
# $20.84     1
# $106.24    1
# $41.57     1
# $17.00     1
# $18.40     1
# $49.57     1
# $37.05     1
# $60.88     1
# $43.82     1
# $35.51     1
# $74.84     1
# $53.58     1
# $73.34     1
# $62.56     1
# $37.78     1
# $33.67     1
# $162.28    1
# $67.88     1
# $40.99     1
# $20.53     1
# $55.19     1
# $52.07     1
# Name: close, Length: 711, dtype: int64

# %%
vol.size
#returns scalar number
# Out:
# 750

# %%
vol.shape
#returns a tuple
# Out:
# (750,)

# %%
len(vol)
# Out:
# 750

# %%
vol.count()
#returns number of non missing values
# Out:
# 750

# %%
cl.count()
# Out:
# 750

# %%
vol.describe()
# Out:
# count    7.500000e+02
# mean     1.175478e+08
# std      1.584381e+08
# min      9.718851e+06
# 25%      3.086624e+07
# 50%      5.306088e+07
# 75%      1.327218e+08
# max      1.453439e+09
# Name: volume, dtype: float64

# %%
df_j.describe()
# Out:
#           quarter        volume  percent_change_price  \
# count  750.000000  7.500000e+02            750.000000
# mean     1.520000  1.175478e+08              0.050262
# std      0.499933  1.584381e+08              2.517809
# min      1.000000  9.718851e+06            -15.422900
# 25%      1.000000  3.086624e+07             -1.288053
# 50%      2.000000  5.306088e+07              0.000000
# 75%      2.000000  1.327218e+08              1.650888
# max      2.000000  1.453439e+09              9.882230
#
#        percent_change_volume_over_last_wk  previous_weeks_volume  \
# count                          720.000000           7.200000e+02
# mean                             5.593627           1.173876e+08
# std                             40.543478           1.592322e+08
# min                            -61.433175           9.718851e+06
# 25%                            -19.804284           3.067832e+07
# 50%                              0.512586           5.294556e+07
# ...

# %%
df_j.isnull().any()
# Out:
# quarter                               False
# stock                                 False
# date                                  False
# open                                  False
# high                                  False
# low                                   False
# close                                 False
# volume                                False
# percent_change_price                  False
# percent_change_volume_over_last_wk     True
# previous_weeks_volume                  True
# next_weeks_open                       False
# next_weeks_close                      False
# percent_change_next_weeks_price       False
# days_to_next_dividend                 False
# percent_return_next_dividend          False
# dtype: bool

# %%
#replacing missing values within a series
volclwk = df_j['percent_change_volume_over_last_wk']
volclwk = volclwk.fillna(np.mean(volclwk))
volclwk.isnull().any()
# Out:
# False

# %% [markdown]
# ### working with operators on a series

# %%
not(5<=9)
# Out:
# False

# %%
7 in [1,6,8]
# Out:
# False

# %%
set([1,2,3,6]) & set([3,6,7,5])
# Out:
# {3, 6}

# %% [markdown]
# ### chaining series method together

# %%
# Method Chaining is the sequential invocation of methods using dot notation

# %%
cl.value_counts().head(3)
# Out:
# $33.07    3
# $46.25    3
# $41.52    3
# Name: close, dtype: int64

# %%
cl.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Making the Index Meaningful

# %%
#using the date as index
date = df_j.set_index('date')
date
# Out:
#            quarter stock    open    high     low   close     volume  \
# date
# 1/7/2011         1    AA  $15.82  $16.72  $15.78  $16.42  239655616
# 1/14/2011        1    AA  $16.71  $16.71  $15.64  $15.97  242963398
# 1/21/2011        1    AA  $16.19  $16.38  $15.60  $15.79  138428495
# 1/28/2011        1    AA  $15.87  $16.63  $15.82  $16.13  151379173
# 2/4/2011         1    AA  $16.18  $17.39  $16.18  $17.14  154387761
# 2/11/2011        1    AA  $17.33  $17.48  $16.97  $17.37  114691279
# 2/18/2011        1    AA  $17.39  $17.68  $17.28  $17.28   80023895
# 2/25/2011        1    AA  $16.98  $17.15  $15.96  $16.68  132981863
# 3/4/2011         1    AA  $16.81  $16.94  $16.13  $16.58  109493077
# 3/11/2011        1    AA  $16.58  $16.75  $15.42  $16.03  114332562
# 3/18/2011        1    AA  $15.95  $16.33  $15.43  $16.11  130374108
# 3/25/2011        1    AA  $16.38  $17.24  $16.26  $17.09   95550392
# 1/7/2011         1   AXP  $43.30  $45.60  $43.11  $44.36   45102042
# ...

# %%
date.reset_index()
# Out:
#           date  quarter stock    open    high     low   close     volume  \
# 0     1/7/2011        1    AA  $15.82  $16.72  $15.78  $16.42  239655616
# 1    1/14/2011        1    AA  $16.71  $16.71  $15.64  $15.97  242963398
# 2    1/21/2011        1    AA  $16.19  $16.38  $15.60  $15.79  138428495
# 3    1/28/2011        1    AA  $15.87  $16.63  $15.82  $16.13  151379173
# 4     2/4/2011        1    AA  $16.18  $17.39  $16.18  $17.14  154387761
# 5    2/11/2011        1    AA  $17.33  $17.48  $16.97  $17.37  114691279
# 6    2/18/2011        1    AA  $17.39  $17.68  $17.28  $17.28   80023895
# 7    2/25/2011        1    AA  $16.98  $17.15  $15.96  $16.68  132981863
# 8     3/4/2011        1    AA  $16.81  $16.94  $16.13  $16.58  109493077
# 9    3/11/2011        1    AA  $16.58  $16.75  $15.42  $16.03  114332562
# 10   3/18/2011        1    AA  $15.95  $16.33  $15.43  $16.11  130374108
# 11   3/25/2011        1    AA  $16.38  $17.24  $16.26  $17.09   95550392
# ...
